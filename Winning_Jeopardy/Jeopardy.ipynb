# %% [markdown]
# ## How to win in Jeopardy
#
# The goal of the project is to find some pattern in asked questions in Jeopardy show. Those patter may be helpful in winning show.

# %%
import pandas as pd
import numpy as np
import re

from scipy.stats.mstats import chisquare

# %%
jeopardy = pd.read_csv("jeopardy.csv")

# %%
jeopardy.head()
# Out:
#    show_number   air_date      round                         category value  \
# 0         4680 2004-12-31  Jeopardy!                          HISTORY  $200
# 1         4680 2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680 2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680 2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680 2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             question      answer  \
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams
#
#                                       clean_question clean_answer  \
# 0  for the last 8 years of his life galileo was u...   copernicus
# 1  no 2 1912 olympian football star at carlisle i...   jim thorpe
# 2  the city of yuma in this state has a record av...      arizona
# 3  in 1963 live on the art linkletter show this c...    mcdonalds
# 4  signer of the dec of indep framer of the const...   john adams
#
#    clean_value  answer_in_question  question_overlap  high_value
# 0          200                 0.0          0.000000         0.0
# 1          200                 0.0          0.000000         0.0
# 2          200                 0.0          0.000000         0.0
# 3          200                 0.0          0.200000         0.0
# 4          200                 0.0          0.142857         0.0

# %%
jeopardy.columns = jeopardy.columns.str.lower().str.strip().str.replace(" ","_")

# %%
def normalize_text(string):
    lowered = string.lower()
    s = re.sub("[^A-Za-z0-9\s]",'',lowered)
    s = re.sub("\s+",' ',s)
    s = s.strip()
    return s

# %%
jeopardy["clean_question"] = jeopardy["question"].apply(normalize_text)
jeopardy["clean_answer"]  = jeopardy["answer"].apply(normalize_text)

# %%
def convert_value(string):
    s = re.sub("[^A-Za-z0-9\s]",'',string)
    try:
        int_val = int(s)
    except ValueError:
        int_val = 0
    return int_val

# %%
jeopardy["clean_value"] = jeopardy["value"].apply(convert_value)
jeopardy["air_date"] = pd.to_datetime(jeopardy["air_date"])

# %%
jeopardy.head()
# Out:
#    show_number   air_date      round                         category value  \
# 0         4680 2004-12-31  Jeopardy!                          HISTORY  $200
# 1         4680 2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680 2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680 2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680 2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             question      answer  \
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams
#
#                                       clean_question clean_answer  \
# 0  for the last 8 years of his life galileo was u...   copernicus
# 1  no 2 1912 olympian football star at carlisle i...   jim thorpe
# 2  the city of yuma in this state has a record av...      arizona
# 3  in 1963 live on the art linkletter show this c...    mcdonalds
# 4  signer of the dec of indep framer of the const...   john adams
#
#    clean_value  answer_in_question  question_overlap  high_value
# 0          200                 0.0          0.000000         0.0
# 1          200                 0.0          0.083333         0.0
# 2          200                 0.0          0.100000         0.0
# 3          200                 0.0          0.111111         0.0
# 4          200                 0.0          0.333333         0.0

# %%
def remove_words_arr(words_to_remove,arr):
    for word in words_to_remove:
        if word in arr:
            arr.remove(word)

def answer_in_question(row):
    split_answer = row["clean_answer"].split(" ")
    split_question = row["clean_question"].split(" ")
    match_count = 0
    words_to_remove = ["the","a","an"]
    remove_words_arr(words_to_remove,split_answer)
    remove_words_arr(words_to_remove,split_question)
    if len(split_answer)==0:
        return 0
    for word_answer in split_answer:
        if word_answer in split_question:
            match_count += 1
            
    return match_count/len(split_answer)

# %%
jeopardy["answer_in_question"] = jeopardy.apply(answer_in_question,axis=1)

# %%
jeopardy["answer_in_question"].mean()
# Out:
# 0.04283139120881008

# %% [markdown]
# To check whether answer is deducible from the question I splitted all the answer and question by space and count the number of the answer words which appears in the question. The column answer_in_question contains ratio of the number of answer words which exist in question to number of total words. It will allow to answer if answer can be answered based on question.

# %%
question_overlap = []
terms_used = set()

def remove_short_words(arr):
    for word in split_question:
        if len(word)<6:
            split_question.remove(word)
jeopardy.sort_values(by="air_date")

for row in jeopardy.sort_values(by="air_date").iterrows():
    split_question = row[1]["clean_question"].split(" ")
    remove_short_words(split_question)
    match_count = 0
    for word in split_question:
        if word in terms_used:
            match_count += 1
        terms_used.add(word)
    if match_count>0:
        match_count = match_count/len(split_question)
    question_overlap.append(match_count)

jeopardy["question_overlap"] = question_overlap
jeopardy["question_overlap"].mean()
# Out:
# 0.7989239490508186

# %% [markdown]
# By counting the matching words from question, which exists in previous questions I wanted to know how is the possible to get similiar question to the previous ones. The mean words which exists in earlier questions seems to be very high. It tells that 80% of the words in the question has been in previous ones. The problem with this score could be that the words in specific question could have mix of many other questions, which give huge value of repeated words. However, it does not has to be truth that it is related to any specific previous question. Anyway it is nice to make further investigation to see this outcome closer.

# %%
jeopardy.loc[jeopardy["clean_value"]>800,"high_value"] = 1
jeopardy.loc[jeopardy["clean_value"]<=800,"high_value"] = 0

# %%
terms_used
# Out:
# {'cranio',
#  'lynda',
#  'sunlight',
#  'mountaina',
#  'publishing',
#  'automobile',
#  'woody',
#  'cooper',
#  'arturo',
#  'presiding',
#  'astrologer',
#  'claustrophobia',
#  'brenda',
#  'g',
#  'hrefhttpwwwjarchivecommedia20091014j09jpg',
#  'mortals',
#  'almighty',
#  'chair',
#  'downey',
#  'dispensary',
#  'estrogen',
#  'morial',
#  'hiphop',
#  'poplicola',
#  'stoller',
#  'partagas',
#  'zee',
#  'pastorship',
#  'dhaka',
#  'outfit',
#  'sympathies',
#  'cardiac',
#  'piggies',
#  'onethird',
#  'cruella',
#  'corporate',
#  'mural',
#  'medals',
#  'quatrains',
#  'abbey',
#  'literature',
#  'immediate',
#  'crossed',
#  'lanai',
#  'doodah',
#  'sundew',
#  'petticoats',
#  'camp',
#  '2masted',
#  'person',
#  'beta',
#  'differently',
#  '4th',
#  'peddles',
#  'invigorate',
#  'stairs',
#  'makola',
#  'sunset',
#  'snowed',
#  'viceia',
#  'blossomed',
#  'undertake',
#  'hobble',
#  'gemini',
#  'embarrassment',
#  'text',
#  'borglum',
#  'heroic',
#  'herring',
#  '1877',
#  'hippophagy',
#  'meltdown',
#  'hrefhttpwwwjarchivecommedia20040521j22jpg',
#  'carmel',
#  'matlock',
#  'antipsychotic',
#  'hessekassel',
#  'approved',
#  'bitches',
#  'klaproth',
#  'rotating',
#  'stitches',
#  'showguidebioalexphp',
#  'whites',
#  'storace',
#  'polynesian',
#  'greekborn',
#  'governed',
#  'except',
#  'gravy',
#  'hampshirea',
#  'saddlers',
#  'realigned',
#  '1827',
#  'arches',
#  'fum',
#  'exempress',
#  'firmly',
#  'mccourt',
#  'translates',
#  'seurat',
#  '7letter',
#  'mckellen',
#  'shocked',
#  'nagano',
#  'hrefhttpwwwjarchivecommedia20061012dj28ajpg',
#  'neruda',
#  'pussycat',
#  'snapped',
#  'trafficespecially',
#  'lesney',
#  'nineveh',
#  'ajnachakra',
#  'hardly',
#  'cheeck',
#  'gilpin',
#  'mameli',
#  'serve',
#  'shorttailed',
#  'waverly',
#  'worm',
#  'preferred',
#  'kabuki',
#  'abend',
#  'kerri',
#  'familys',
#  'botanist',
#  'acutely',
#  'grandparents',
#  'bros',
#  'sweets',
#  'rani',
#  'automatic',
#  'toothless',
#  'quintet',
#  'strain',
#  'compromising',
#  'figments',
#  'funeral',
#  'prisons',
#  'honorius',
#  '112mile',
#  'crystallography',
#  'hannabarbera',
#  'salukis',
#  'fletchers',
#  'bodys',
#  'rounded',
#  'brunette',
#  'chances',
#  'traffic',
#  'memed',
#  'undulation',
#  'packed',
#  'bagger',
#  'predominant',
#  'butthead',
#  'scarface',
#  'francine',
#  'grewal',
#  'romanoff',
#  'donors',
#  'brodick',
#  'weatherwise',
#  'reddi',
#  '52nd',
#  'susann',
#  'dick',
#  'wolfdog',
#  'affer',
#  'bulfinch',
#  'specialties',
#  'print',
#  'wickthis',
#  'omitted',
#  'molecules',
#  'sample',
#  'subscribe',
#  'unchartered',
#  'squawk',
#  'ogoshen',
#  'heroine',
#  'hannah',
#  'tuskegee',
#  'noire',
#  'bonnie',
#  'nu',
#  'missions',
#  'frame',
#  'derr',
#  'indistinguishable',
#  'wascally',
#  'schultz',
#  'protons',
#  'edvard',
#  'relaxed',
#  'aladdin',
#  'fake',
#  'donegal',
#  'hightech',
#  'abdulaziz',
#  'achilles',
#  'cadillac',
#  'prokofiev',
#  'hrefhttpwwwjarchivecommedia20060601j08wmvthesea',
#  'cooped',
#  'entrees',
#  'hrefhttpwwwjarchivecommedia20061016dj17mp3oh',
#  'bestremembered',
#  'mcdavid',
#  'stringbending',
#  'edam',
#  'aagood',
#  'morris',
#  'revive',
#  'algonquianspeaking',
#  'rawling',
#  'cyprus',
#  'traumdeutung',
#  'bohemia',
#  'loneliness',
#  'syrias',
#  'hippocratic',
#  'claras',
#  'skunks',
#  'hrefhttpwwwjarchivecommedia20070221dj08ajpg',
#  'sidesjapanese',
#  'tongue',
#  'devoid',
#  'stoppard',
#  'grenades',
#  'nightclub',
#  'slabs',
#  '8yearold',
#  'varsovians',
#  'insubordination',
#  'massproduction',
#  'accessories',
#  'migrants',
#  'switzer',
#  'phones',
#  'viceversa',
#  'checkers',
#  '16yearold',
#  'amphibians',
#  'material',
#  'annapolis',
#  'convenience',
#  'luftwaffe',
#  'fertig',
#  'off',
#  'reptile',
#  'hrefhttpwwwjarchivecommedia20041109dj07mp3herea',
#  'hrefhttpwwwjarchivecommedia20050303j08jpg',
#  'intent',
#  'hrefhttpwwwjarchivecommedia20060227dj25jpg',
#  'targetblankfollowinga',
#  'boutique',
#  'infused',
#  'hood',
#  'potions',
#  'hrefhttpwwwjarchivecommedia20060725j06mp3followinga',
#  'susan',
#  'moisture',
#  'jemima',
#  'mcfly',
#  'dewdrop',
#  'bluffs',
#  'hoop',
#  'stoned',
#  'blind',
#  'slumlord',
#  'borrowed',
#  'baptized',
#  'yuma',
#  'acadia',
#  'leningrad',
#  '1987',
#  'capacitance',
#  'travis',
#  'temps',
#  'justinian',
#  'embattled',
#  'parrot',
#  'targetblankvideo',
#  'humphrey',
#  'beanpole',
#  'arrangement',
#  'hrefhttpwwwjarchivecommedia20090211j24wmvthisa',
#  'anatomical',
#  'torture',
#  'satinwood',
#  'whose',
#  'hoops',
#  'detroit',
#  'entered',
#  'macnicol',
#  'canal',
#  'mmmbop',
#  'cauldron',
#  'unity',
#  'capitals',
#  '1676',
#  'purpletinged',
#  'doffed',
#  'cd',
#  'bokmal',
#  'addressing',
#  'flames',
#  'macduff',
#  'spotless',
#  'succeed',
#  'humped',
#  'beauties',
#  'recognized',
#  'iskenderun',
#  'custody',
#  'swizz',
#  'shotforshot',
#  'francon',
#  'deckard',
#  'tori',
#  'bounced',
#  'crowds',
#  'baked',
#  'jets',
#  'since',
#  'aquamarine',
#  'cambria',
#  'pointy',
#  'enfants',
#  'asta',
#  'partial',
#  'albrecht',
#  'expense',
#  'dodging',
#  'ismail',
#  'milne',
#  'fils',
#  'moviewithinamovie',
#  'ecuador',
#  'advancement',
#  'mickey',
#  'outbreak',
#  'hawke',
#  'displace',
#  'tussle',
#  'musics',
#  'edward',
#  '29year',
#  '1637',
#  'receptions',
#  'sullivan',
#  'rathbun',
#  'pointing',
#  'braganza',
#  'targetblankplayeda',
#  'bivalves',
#  'gremlins',
#  'adriatic',
#  'exmrs',
#  'organizer',
#  '45th',
#  '178085',
#  'wwwicannthis',
#  'rescued',
#  'venatus',
#  'dusted',
#  'roughly',
#  'jerrid',
#  'coronados',
#  'reincarnation',
#  'looters',
#  'basketball',
#  'quincy',
#  'criticisms',
#  'rudolf',
#  'equally',
#  'hrefhttpwwwjarchivecommedia20020702dj18jpg',
#  'plot',
#  'plead',
#  'pain',
#  'disliked',
#  'tours',
#  'hrefhttpwwwjarchivecommedia20091124dj25jpg',
#  '1593',
#  'sodom',
#  'fodors',
#  'ishmael',
#  'services',
#  'cautions',
#  'knot',
#  '118',
#  'represented',
#  'galileo',
#  '12gauge',
#  'tigrett',
#  'scary',
#  'mideast',
#  'cochlear',
#  'sublicius',
#  'tendera',
#  'aristotle',
#  'chinos',
#  'needed',
#  'labyrinth',
#  'whereby',
#  'hrefhttpwwwjarchivecommedia20070719j20jpg',
#  'watchmaker',
#  'zhdanov',
#  'hrefhttpwwwjarchivecommedia20050121dj27jpg',
#  'gillespie',
#  'scripps',
#  'hrefhttpwwwjarchivecommedia20060127j22jpg',
#  'livin',
#  'okinawan',
#  'insure',
#  'stonea',
#  'delectably',
#  'claire',
#  'coming',
#  'barred',
#  'drill',
#  'yitzhak',
#  'mockingly',
#  'exercisers',
#  'zbigniew',
#  '1972',
#  'pillowcases',
#  'yoho',
#  'evident',
#  'barren',
#  'kalifornia',
#  'coopera',
#  'hopped',
#  'crumbs',
#  'macgraw',
#  'shagreen',
#  'flecked',
#  'chastain',
#  'jeopardy',
#  'directly',
#  'invention',
#  'attach',
#  'catkins',
#  'lounge',
#  'pompom',
#  'semipublic',
#  'quest',
#  'sharpen',
#  'fifteen',
#  'giles',
#  'stanford',
#  'cashier',
#  'nuclei',
#  'valparaiso',
#  'pfc',
#  'charleston',
#  'container',
#  'braided',
#  'annexing',
#  'plissken',
#  'connects',
#  'cumulonimbus',
#  'pacino',
#  'zihuatanejo',
#  'phenomenally',
#  'actorwriter',
#  'isatellite',
#  'ketchup',
#  'replanned',
#  'governor',
#  'forcing',
#  'blended',
#  'pastures',
#  'francois',
#  'peptic',
#  '2block',
#  'coughing',
#  'hrefhttpwwwjarchivecommedia20100111dj26jpg',
#  'domenikos',
#  'mapa',
#  'hrefhttpwwwjarchivecommedia20091208dj15ajpg',
#  'eardrum',
#  'mongols',
#  'dempsey',
#  'leipzig',
#  'consent',
#  'skill',
#  'celebrated',
#  'oo',
#  'brad',
#  'nigerianled',
#  'werepanther',
#  'trafficking',
#  'engulfed',
#  'mugs',
#  '1892',
#  'hrefhttpwwwjarchivecommedia20090105dj01bjpg',
#  'judges',
#  'port',
#  'glue',
#  'pleasence',
#  'paints',
#  'pondering',
#  'theophobia',
#  'intentions',
#  'brooks',
#  'funniest',
#  'caddyshack',
#  'sees',
#  '149000',
#  'inaugurated',
#  'charlotte',
#  'afghan',
#  'promises',
#  'spoiler',
#  'appropriately',
#  'strumming',
#  'regarding',
#  'notwithstanding',
#  'pointillist',
#  'confusing',
#  'unbeknownst',
#  'marat',
#  'suspicion',
#  'dekalb',
#  'kingdom',
#  'plow',
#  'infanta',
#  'shrines',
#  'ealy',
#  'diction',
#  'undigested',
#  'algernon',
#  'frumious',
#  'devout',
#  '2222',
#  'embrace',
#  'tigers',
#  'counselor',
#  'cystic',
#  '1947',
#  'affect',
#  'polite',
#  'scarpia',
#  'leadermilitary',
#  'palmetto',
#  'hrefhttpwwwjarchivecommedia20090205dj21jpg',
#  'gleans',
#  'archangel',
#  'police',
#  'bourbonmadagascar',
#  'orchards',
#  'teenager',
#  'eruptions',
#  '236',
#  'dozier',
#  'incompetence',
#  'chris',
#  'goat',
#  'remedies',
#  'thistake',
#  'tea',
#  'segels',
#  'comet',
#  'sally',
#  '1s',
#  'stedelijk',
#  'clarify',
#  'hopefully',
#  'gerostete',
#  'hrefhttpwwwjarchivecommedia20060206dj04jpg',
#  'moana',
#  'overlords',
#  'protested',
#  'sprinkle',
#  'cobs',
#  'bowsfor',
#  '1805',
#  'neuman',
#  'ejected',
#  'vamp',
#  'lebanese',
#  'encantado',
#  'hrefhttpwwwjarchivecommedia20091208dj17jpg',
#  'nobile',
#  'tennis',
#  'best',
#  'jerseyborn',
#  'cookie',
#  'brigades',
#  'dreadfully',
#  'zinoviev',
#  'enthusiasts',
#  'beatified',
#  'midwest',
#  'ribosomal',
#  'sight',
#  'hrefhttpwwwjarchivecommedia20040706j09jpg',
#  'surprise',
#  'breakout',
#  'delicious',
#  'trucker',
#  'steinbeck',
#  'halfbrothers',
#  'organizing',
#  'mockingbird',
#  'aimlessly',
#  'weizmann',
#  'marion',
#  'bennys',
#  'titles',
#  'already',
#  'festival',
#  'thuggishruggishbone',
#  'which',
#  'wadlows',
#  'ore',
#  'esau',
#  'worshiper',
#  'persuasive',
#  'frontiera',
#  'stocking',
#  'cloudy',
#  'whiskies',
#  'overstuffed',
#  'rimini',
#  'souvenir',
#  'veterans',
#  'tolbert',
#  'tapped',
#  'representation',
#  'chicagobased',
#  'saban',
#  'hanseatic',
#  'lovejoy',
#  'no',
#  'deers',
#  'meck',
#  'might',
#  '1806',
#  'woodrow',
#  'crimean',
#  'oversimplify',
#  'doorcheck',
#  'hail',
#  'minnesingers',
#  'assassins',
#  '1791',
#  'asian',
#  'wonderboykaput',
#  'martyrdom',
#  'noise',
#  'poisoned',
#  'bloodsucking',
#  'crimefighting',
#  'puppyraising',
#  'bed',
#  'highgrade',
#  'alfonso',
#  'tax',
#  'bringing',
#  'embalming',
#  'beautiful',
#  'mandy',
#  'transparent',
#  'modernqueen',
#  'freer',
#  '736',
#  'explorations',
#  'spirits',
#  '1550',
#  'barbels',
#  'hrefhttpwwwjarchivecommedia20091027dj07jpg',
#  'absalom',
#  'godson',
#  '1785',
#  'stripes',
#  'waysfor',
#  'beasts',
#  'coward',
#  'theodosius',
#  'henry',
#  'intoned',
#  'audrey',
#  'darkened',
#  'regatta',
#  'soleus',
#  'grease',
#  'eroica',
#  'safeguard',
#  'sayin',
#  'giuoco',
#  'gorbachev',
#  'westerntype',
#  'hrefhttpwwwjarchivecommedia20091016dj04jpg',
#  'skunk',
#  'gargantuan',
#  'julius',
#  'ostrich',
#  'limits',
#  'mattresses',
#  'survivor',
#  'manuel',
#  'uncertain',
#  'macaques',
#  'invalid',
#  'goldblum',
#  'connected',
#  'arthurs',
#  'corpuscles',
#  'trefoil',
#  'grinding',
#  'simulated',
#  'easters',
#  'rognoni',
#  'offseason',
#  'makin',
#  'nations',
#  'fjord',
#  'clair',
#  'handiwork',
#  'editors',
#  'archenemy',
#  'hrefhttpwwwjarchivecommedia20090504dj30wmvthesea',
#  'villager',
#  'hrefhttpwwwjarchivecommedia20091218j16jpg',
#  'russia',
#  'delovely',
#  'paprikash',
#  'hrefhttpwwwjarchivecommedia20080313dj29jpg',
#  '1247000',
#  'hrefhttpwwwjarchivecommedia20061016dj18mp3hello',
#  'sensibility',
#  'winooski',
#  '6wicket',
#  'tribe',
#  'albio',
#  'cultivated',
#  '1729',
#  'praiseworthy',
#  'jackie',
#  'chefs',
#  'logical',
#  'rebuilt',
#  'atticus',
#  'hagia',
#  'column',
#  'maneating',
#  'hadnt',
#  'compartment',
#  'lacks',
#  'healthiest',
#  'atmosphere',
#  'jordanian',
#  'symphonie',
#  'colonists',
#  'tbilisi',
#  'members',
#  'hrefhttpwwwjarchivecommedia20080602dj19ajpg',
#  'hearttoheart',
#  'electron',
#  'safety',
#  '1941',
#  '1220',
#  'physicsa',
#  'hrefhttpwwwjarchivecommedia20090514dj25wmvcluesa',
#  'machado',
#  'leon',
#  'oxymoron',
#  'charming',
#  'proves',
#  'singeractor',
#  'adelheid',
#  'graphing',
#  'didact',
#  'neil',
#  'volador',
#  'wind',
#  'bumblen',
#  'bestknown',
#  'juntas',
#  'crossslotted',
#  'chasmic',
#  'ophelia',
#  'wiedlin',
#  'carnarvon',
#  'huddle',
#  'jacobsons',
#  'prescription',
#  'sioux',
#  '1782',
#  'mcgraw',
#  'tights',
#  'hrefhttpwwwjarchivecommedia20071204j30jpg',
#  'preserved',
#  'musketeers',
#  'caetano',
#  'silhouette',
#  'ribbonshaped',
#  'hair',
#  'hireling',
#  'cappelletto',
#  'targetblankdan',
#  'suffered',
#  'atlanta',
#  'lobsters',
#  'criticize',
#  'goodlooking',
#  'hrefhttpwwwjarchivecommedia20111024j26bjpg',
#  'pancakes',
#  'wasteful',
#  '61',
#  'thread',
#  'rodents',
#  'marrowless',
#  'marcus',
#  'marble',
#  'vanquished',
#  'targetblankheresa',
#  '125',
#  'viva',
#  'overpower',
#  'powdermaker',
#  '255foot',
#  'obstruction',
#  'it',
#  'granth',
#  'mogadishu',
#  'attend',
#  'strange',
#  'condensed',
#  'chinas',
#  'chiefly',
#  'hrefhttpwwwjarchivecommedia20081222j19jpg',
#  'location',
#  'fitting',
#  'mortar',
#  'raucous',
#  'square',
#  '1901',
#  'continuous',
#  '1271',
#  'theroux',
#  'knowsi',
#  'projectiles',
#  'past',
#  'converted',
#  'moneys',
#  'indianburialgroundbrook',
#  'demos',
#  'baxter',
#  'jewelry',
#  'houseelf',
#  'yiddish',
#  'rodney',
#  'sermon',
#  'brasilia',
#  'ewr',
#  'falcos',
#  'block',
#  'da',
#  'aerial',
#  'lawrence',
#  'length',
#  '1836',
#  'riverside',
#  'thatcher',
#  'malleus',
#  '50star',
#  'deceptively',
#  'harpy',
#  'versailles',
#  'andersen',
#  '1617',
#  'bitesized',
#  'pollock',
#  'natl',
#  'transmitters',
#  'impeachment',
#  'troops',
#  'inn',
#  'bonneville',
#  'lampton',
#  'seduction',
#  'jealous',
#  'dessau',
#  'mariette',
#  'countries',
#  '1694',
#  'gosudarstvennoy',
#  'togo',
#  'majorca',
#  'freshly',
#  'arabic',
#  'julioclaudian',
#  'prison',
#  'creosote',
#  'trujano',
#  'contented',
#  'cosmos',
#  'osloborn',
#  'fleche',
#  'goede',
#  'thimphu',
#  'chula',
#  'samantha',
#  'robson',
#  'memoirs',
#  'canaanites',
#  'paleface',
#  'bagatelle',
#  'marlowe',
#  'unrefined',
#  'elisabeth',
#  'paterson',
#  '3',
#  'suspend',
#  'lovin',
#  'books',
#  'mukherjee',
#  'noted',
#  'mannix',
#  'hrefhttpwwwjarchivecommedia20080722dj24wmvcheryl',
#  'topselling',
#  'jungles',
#  'pilgrims',
#  'tu',
#  'waifish',
#  'glands',
#  'savannahs',
#  'court',
#  'pois',
#  'newt',
#  'winslet',
#  'newseum',
#  'enigma',
#  'osment',
#  'einkorn',
#  'enthused',
#  'blowgun',
#  'romano',
#  '5',
#  'server',
#  'hrefhttpwwwjarchivecommedia20080509j24jpg',
#  'across',
#  'illegal',
#  'stroke',
#  'prakan',
#  'totaled',
#  'mischiefmaker',
#  'altered',
#  'underdog',
#  'saintexupery',
#  'captivity',
#  'cluster',
#  '1929',
#  'verne',
#  'whales',
#  'grandview',
#  'shopping',
#  'maris',
#  'asgard',
#  'plane',
#  'petrie',
#  'hudson',
#  'glitch',
#  'contacting',
#  'hrefhttpwwwjarchivecommedia20050315dj18jpg',
#  'ave',
#  'straussler',
#  'cataria',
#  'wildlife',
#  'electrician',
#  'mccord',
#  'robbery',
#  'oneword',
#  'difficult',
#  '10letter',
#  'pail',
#  'tibetan',
#  'magazinecom',
#  'do',
#  'thelonious',
#  'hrefhttpwwwjarchivecommedia20110121dj17jpg',
#  'buddy',
#  'book',
#  'passage',
#  'heismans',
#  'bridges',
#  'ugly',
#  'durobrivae',
#  'spiceinfused',
#  'tishri',
#  'cusack',
#  'carville',
#  'hit',
#  'megabytes',
#  'ocalan',
#  ...}

# %%
def count_high_low(word):
    low_count = 0
    high_count = 0
    for row in jeopardy.iterrows():
        row = row[1]
        split_question = row["clean_question"].split(" ")
        if word in split_question:
            if row["high_value"] == 1:
                high_count += 1 
            else:
                low_count += 1
    return high_count,low_count
observed_expected = [] 
comparision_terms = list(terms_used)[:5]
for term in comparision_terms:
    observed_expected.append(count_high_low(term))

# %%
observed_expected
# Out:
# [(0, 1), (0, 1), (0, 3), (1, 1), (3, 7)]

# %%
comparision_terms
# Out:
# ['cranio', 'lynda', 'sunlight', 'mountaina', 'publishing']

# %%
high_value_count = (jeopardy["high_value"]==1).sum()
low_value_count = (jeopardy["high_value"]==0).sum()

# %%
chi_squared = [] 
for high,low in observed_expected:
    total = high + low
    total_prop = total/len(jeopardy)
    exp_high = total_prop*high_value_count
    exp_low = total_prop*low_value_count
    chi_squared.append(chisquare([high,low],[exp_high,exp_low]))

# %%
chi_squared
# Out:
# [Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=1.205888538380652, pvalue=0.27214791766902047),
#  Power_divergenceResult(statistic=0.4448774816612795, pvalue=0.5047776487545996),
#  Power_divergenceResult(statistic=0.008630851497838939, pvalue=0.9259811180040979)]

# %% [markdown]
# Any of all tested values has significant differences between high and low values questions. Frequencies is also very low what makes the test insignificant.
